# %% [markdown]
# ![employee-attrition.jpg](attachment:employee-attrition.jpg)

# %% [markdown]
# # Aim: Understanding the Attrition in HR

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# Every year a lot of companies hire a number of employees. The companies invest time and money in training those employees, not just this but there are training programs within the companies for their existing employees as well. The aim of these programs is to increase the effectiveness of their employees. But where HR Analytics fit in this? and is it just about improving the performance of employees?
#
# HR Analytics
#
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.
#
# Attrition in HR
#
# Attrition in human resources refers to the gradual loss of employees overtime. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture, and motivation systems that help the organization retain top employees.
#
# How does Attrition affect companies? and how does HR Analytics help in analyzing attrition? We will discuss the first question here and for the second question, we will write the code and try to understand the process step by step.
#
# Attrition affecting Companies
#
# A major problem in high employee attrition is its cost to an organization. Job postings, hiring processes, paperwork, and new hire training are some of the common expenses of losing employees and replacing them. Additionally, regular employee turnover prohibits your organization from increasing its collective knowledge base and experience over time. This is especially concerning if your business is customer-facing, as customers often prefer to interact with familiar people. Errors and issues are more likely if you constantly have new workers.

# %% [markdown]
# ## Question:

# %% [markdown]
# 1. How does Attrition affect companies?
# Answer: In todays enviroment, companies are spend huge amount on hiring and training employee. If an employee quit the job, it cause loss of time and money. After analysing all the parameter, we came to conclusion Over time, Marital status, Job profile and department, playing big role in Attrition. which lead lo loss of employee.
# Due to Attrition compnay loss valuable time and money both, At the end company, not able to achive the goal.
# 2. How does HR Analytics help in analyzing attrition?

# %% [markdown]
# ##### Imorting required library

# %%
import numpy as np
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ##### Load dataste

# %%
data= pd.read_csv('HR-Employee-Attrition.csv')

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # Data Analysis

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# 1.Here the dataset having 1470 Rows and 35 columns.
# 2.Data having 26 integer columns and 9 object columns.
# 3.Attrition is our target column.
# 4. All other columns are feature columns.

# %% [markdown]
# ##### Checking  null values

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# Luckly, We are not having any null value in our dataset.
# Lets move ahead and understand our data set, features.

# %% [markdown]
# Lets devide data set into catagorial and Numerial features columns for better data handling.

# %%
cat_features= data.select_dtypes(include=[np.object])
cat_features
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %% [markdown]
# In our dataset, 9 columns are Categorical columns.
# Attrition is our target column, we need to predict it using input features.
# Lets check First check the number of unique values in each categorical column.

# %%
cat_features.nunique()
# Out:
# Attrition         2
# BusinessTravel    3
# Department        3
# EducationField    6
# Gender            2
# JobRole           9
# MaritalStatus     3
# Over18            1
# OverTime          2
# dtype: int64

# %% [markdown]
# Here we can see all the number of unique values present in the categorical columns.
# Job Role having maximum number of unique values, means we have 9 kind of jobs availabele in data.
# Over18 column having only one value means all the employe are over 18, we can say this colums is not relevent for analysis.

# %%
Num_features = data.select_dtypes(include=[np.number])

# %%
pd.set_option('display.max_columns', None)

# %%
Num_features
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %%
Num_features.nunique()
# Out:
# Age                           43
# DailyRate                    886
# DistanceFromHome              29
# Education                      5
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobSatisfaction                4
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# TotalWorkingYears             40
# TrainingTimesLastYear          7
# WorkLifeBalance                4
# YearsAtCompany                37
# YearsInCurrentRole            19
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# dtype: int64

# %% [markdown]
# EmployeeCount, StandardHours Both the columns having only one unique values, These columns are also not relevent.
# EmployeeNumber is Unique Emplyee Number, this feature also not affecting Attrition.

# %% [markdown]
# ###### Columns we will be deleting in preprocessing stage, are [EmployeeCount,  StandardHours,  EmployeeNumber,  Over18]

# %% [markdown]
# ## EDA

# %% [markdown]
# Here we will be analising our data using plots availble in our seaborn and matplot lib.
# We will use countplot , barplot for univariate analysis of the data.
# For bivariate analysis we will be using Boxplots, Swamplots or even bar charts.

# %% [markdown]
# ## Univariate Analysis

# %%
cat_features.head(3)
# Out:
#   Attrition     BusinessTravel              Department EducationField  Gender  \
# 0       Yes      Travel_Rarely                   Sales  Life Sciences  Female
# 1        No  Travel_Frequently  Research & Development  Life Sciences    Male
# 2       Yes      Travel_Rarely  Research & Development          Other    Male
#
#                  JobRole MaritalStatus Over18 OverTime
# 0        Sales Executive        Single      Y      Yes
# 1     Research Scientist       Married      Y       No
# 2  Laboratory Technician        Single      Y      Yes

# %% [markdown]
# Lets Firts analyse Attrition Percentage.

# %%
plt.figure(figsize=(10, 7))
cat_features.groupby('Attrition').size().plot(kind='pie', autopct='%.2f')

plt.title('Percentage of Employee Attrition', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see 16.12% Attrition, We can say 16.12 percent employee unsatisfied.

# %%
plt.figure(figsize=(20,20))
plotnumber= 1

for column in cat_features:
    if plotnumber<=9:
        ax= plt.subplot(3,3, plotnumber)
        sns.countplot(cat_features[column],)
        plt.xlabel(column, fontsize= 20)
        plt.ylabel('Counts', fontsize= 20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# 1. Attrition: We can see diffrence in value counts, We will balance data using imbalance learn.
# 2. BusinessTravel: BusinessTravel required rarely.
# 3. Department: Most of the pepole are from  Research & Development.
# 4. EducationField: Life Sciences and Medical backgroud pepole are large in numbers.
# 5. Gender: Male employee are more as compared to Female.
# 6. JobRole: Employee workign in Sales Executive profile are more in numbers.
# 7. MaritalStatus: Married Employee are more as compare to single and Divorced.
# 8. Over18: All the employee are over 18.
# 9. OverTime: Most of of the employee are not doing Overtime.

# %%
Num_features.head(3)
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
#
#    JobSatisfaction  MonthlyIncome  MonthlyRate  NumCompaniesWorked  \
# 0                4           5993        19479                   8
# 1                2           5130        24907                   1
# 2                3           2090         2396                   6
#
#    PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# ...

# %%
sns.histplot(Num_features['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# Number of employee in 28-40 age group are more.

# %%
sns.histplot(Num_features['DailyRate'])
# Out:
# <AxesSubplot:xlabel='DailyRate', ylabel='Count'>

# %% [markdown]
# The distribution of Daily rates are almost equal.

# %%
sns.histplot(Num_features['MonthlyIncome'])
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Count'>

# %% [markdown]
# Employee in 2500 range are more as compare to other category.
# Most of the emeployee are getting income in range 25000 - 60000.

# %% [markdown]
# ## Bivariate Aanalysis

# %% [markdown]
# ###### Lets analyse all the features with respect to Target Column.

# %%
for col in cat_features:
    print('\n%s column: '%col)
    print(cat_features[col].value_counts(),'\n'),
    print('='*30)
# Out:
# Attrition column:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
#
# ...
#
# BusinessTravel column:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
#
# ...
#
# Department column:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
#
# ...
#
# EducationField column:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
#
# ...
#
# Gender column:
# Male      882
# Female    588
# Name: Gender, dtype: int64
#
# ...
#
# JobRole column:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# ...

# %%
for col in Num_features:
    print('\n%s column: '%col)
    print(Num_features[col].value_counts(),'\n'),
    print('='*30)
# Out:
# Age column:
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 38    58
# 33    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 24    26
# 25    26
# 47    24
# 49    24
# 55    22
# 53    19
# 48    19
# 51    19
# 52    18
# 54    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: Age, dtype: int64
#
# ...
#
# DailyRate column:
# 691     6
# 1082    5
# 408     5
# 329     5
# 530     5
#        ..
# 708     1
# 713     1
# 717     1
# 719     1
# 1499    1
# Name: DailyRate, Length: 886, dtype: int64
#
# ...
#
# DistanceFromHome column:
# 2     211
# 1     208
# 10     86
# 9      85
# 3      84
# 7      84
# 8      80
# 5      65
# 4      64
# 6      59
# 16     32
# 11     29
# 24     28
# 23     27
# 29     27
# 18     26
# 15     26
# 20     25
# 25     25
# 26     25
# 28     23
# ...

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='BusinessTravel' ,data= cat_features, hue='Attrition')
plt.xlabel('BusinessTravel', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# The workers who travel alot are more likely to quit then other employees.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='Department', data= cat_features, hue='Attrition')
plt.xlabel('Department', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# The workers who are in sales are more likely to quit then other employees.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='EducationField', data= cat_features, hue='Attrition')
plt.xlabel('EducationField', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# The workers who are in Medical are more likely to quit then other employees.

# %% [markdown]
# The workers who are in sales are more likely to quit then other employees.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='Gender', data= cat_features, hue='Attrition')
plt.xlabel('Gender', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# The Male workers are more likely to quit then Female.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='MaritalStatus', data= cat_features, hue='Attrition')
plt.xlabel('MaritalStatus', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# We can see Single workers are more likely to quit than the Married and Divorced.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='OverTime', data= cat_features, hue='Attrition')
plt.xlabel('OverTime', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# Workers who are doing overtime are more likely to quit the job.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='Age',data= data, hue='Attrition')
plt.xlabel('Age', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# Age group 20-34 not having stablity, They are more likely to quit.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='DistanceFromHome',data= data, hue='Attrition')
plt.xlabel('DistanceFromHome', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# Employee who are near to office, are more likely to quite than who are far away from office.
# We can say Employee dont want to work near to their home.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='DailyRate',data= data, hue='Attrition')
plt.xlabel('DailyRate', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# We can see daily rates are not having considereable effect on Attrition.
# Number are almost same.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='EnvironmentSatisfaction',data= data, hue='Attrition')
plt.xlabel('EnvironmentSatisfaction', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# We can see Attrition is almost equal in each stisfaction level.
# EnvironmentSatisfaction is not playing big role for Attrition.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='MonthlyIncome',data= data, hue='Attrition')
plt.xlabel('MonthlyIncome', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# Employee with Lower income more likely to quite the Job.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='MonthlyRate',data= data, hue='Attrition')
plt.xlabel('MonthlyRate', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# Monthly rates not showing any considrable relation.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='NumCompaniesWorked',data= data, hue='Attrition')
plt.xlabel('NumCompaniesWorked', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see who worked with only one company, is more likely to quit the job.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='PercentSalaryHike',data= data, hue='Attrition')
plt.xlabel('PercentSalaryHike', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# PercentSalaryHike have inverse relation, with increase in PercentSalaryHike, Attrition Decrease.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='PerformanceRating',data= data, hue='Attrition')
plt.xlabel('PerformanceRating', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# PerformanceRating affecting Attrition, lesser the rating higher the chance for quiting the job.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='TotalWorkingYears',data= data, hue='Attrition')
plt.xlabel('TotalWorkingYears', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# Employee with less workign years are more likely to quit job.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='YearsSinceLastPromotion',data= data, hue='Attrition')
plt.xlabel('YearsSinceLastPromotion', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# Here we can see most of the employee not completing 2 year, with compnay.
# The are more like to quit after first promotion.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x='JobSatisfaction',data= data, hue='Attrition')
plt.xlabel('JobSatisfaction', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# #### Data Analysis Summery:

# %% [markdown]
# 1. The employee with Low MonthlyIncome, RelationshipSatisfaction, PercentSalaryHike,JobInvolvement,EnvironmentSatisfaction, YearAtCompany, TotalWorkingYears are more likely to quit the job.
# 2. BusinessTravel: Employee with higher BusinessTravel are more likely to quit the job.
# 3. Department: Employee in sale department are more likely to quit the job.
# 4. DistanceFromHome: Employee living very near to home are more likely  quit the job.
# 5. EnvironmentSatisfaction: Employee with low satisfaction are more likely to quit job.
# 6. MaritalStatus: Single Employee are more likely to quit the job.
# 7. NumCompaniesWorked : Employee who worked in  1-2 company only, are more likey to quit the job.
# 8. OverTime: Employee doing over time are more likey to quite the job.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# First Drop the Irelevent columns we identified Earlier.
# columns To drop : [EmployeeCount,  StandardHours,  EmployeeNumber,  Over18]

# %%
data.drop(['EmployeeCount','StandardHours', 'EmployeeNumber', 'Over18'], axis=True, inplace= True)

# %%
data.head(2)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
#
#    Gender  HourlyRate  JobInvolvement  JobLevel             JobRole  \
# 0  Female          94               3         2     Sales Executive
# 1    Male          61               2         2  Research Scientist
#
#    JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0                4        Single           5993        19479
# 1                2       Married           5130        24907
#
#    NumCompaniesWorked OverTime  PercentSalaryHike  PerformanceRating  \
# ...

# %%
data.shape
# Out:
# (1470, 31)

# %%
feature=data.drop('Attrition', axis=1)

# %%
target= data['Attrition']

# %%
data_new= pd.get_dummies(feature,sparse=False, drop_first=True )

# %%
data_new.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41       1102                 1          2                        2
# 1   49        279                 8          1                        3
# 2   37       1373                 2          2                        4
# 3   33       1392                 3          4                        4
# 4   27        591                 2          1                        1
#
#    HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# 0          94               3         2                4           5993
# 1          61               2         2                2           5130
# 2          92               2         1                3           2090
# 3          56               3         1                3           2909
# 4          40               3         1                2           3468
#
#    MonthlyRate  NumCompaniesWorked  PercentSalaryHike  PerformanceRating  \
# ...

# %% [markdown]
# For Target column lets imort label encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le= LabelEncoder()

# %%
Target = le.fit_transform(target)

# %%
data_new['Attritions']= Target

# %%
data_new.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41       1102                 1          2                        2
# 1   49        279                 8          1                        3
# 2   37       1373                 2          2                        4
# 3   33       1392                 3          4                        4
# 4   27        591                 2          1                        1
#
#    HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# 0          94               3         2                4           5993
# 1          61               2         2                2           5130
# 2          92               2         1                3           2090
# 3          56               3         1                3           2909
# 4          40               3         1                2           3468
#
#    MonthlyRate  NumCompaniesWorked  PercentSalaryHike  PerformanceRating  \
# ...

# %%
data_new.corr()
# Out:
#                                         Age  DailyRate  DistanceFromHome  \
# Age                                1.000000   0.010661         -0.001686
# DailyRate                          0.010661   1.000000         -0.004985
# DistanceFromHome                  -0.001686  -0.004985          1.000000
# Education                          0.208034  -0.016806          0.021042
# EnvironmentSatisfaction            0.010146   0.018355         -0.016075
# HourlyRate                         0.024287   0.023381          0.031131
# JobInvolvement                     0.029820   0.046135          0.008783
# JobLevel                           0.509604   0.002966          0.005303
# JobSatisfaction                   -0.004892   0.030571         -0.003669
# MonthlyIncome                      0.497855   0.007707         -0.017014
# MonthlyRate                        0.028051  -0.032182          0.027473
# NumCompaniesWorked                 0.299635   0.038153         -0.029251
# ...

# %%
plt.figure(figsize=(20,20))
data_new.corr()['Attritions'].sort_values(ascending=False).drop(['Attritions']).plot(kind='barh',color='c')
plt.xlabel('Feature', fontsize=14)
plt.ylabel('Columns with target name', fontsize=14)
plt.title('Correlation',fontsize=18)
plt.show()

# %% [markdown]
# Here we can see Feture columns OverTime_Yes, MaritalStatus_Single, JobRole_Sales Representative, BusinessTravel_Travel_Frequently,JobRole_Laboratory Technician,Department_Sales, DistanceFromHome,EducationField_Technical Degree ets having strong correlation with the Target variable.
#
# All the columns on the left of 0.0 are having negative correlation and columns on Right of 0.0 are having positive correlation.

# %%
collist=data_new.columns.values
ncol= 10
nrows= 10

plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows, ncol, i+1)
    sns.boxplot(y=data_new[collist[i]], color='green', orient='x')
    plt.tight_layout()

# %% [markdown]
# Mostly Catagorial columns, so we will not remove any outliers. It will lead to loss a huge data.

# %% [markdown]
# ## Checkign skewness

# %% [markdown]
# Most of the columns in out data are catagorical so we will not check skewness for those and not even remove skewness.
# We will check few coluns seprately.

# %%
data_new.skew()
# Out:
# Age                                  0.413286
# DailyRate                           -0.003519
# DistanceFromHome                     0.958118
# Education                           -0.289681
# EnvironmentSatisfaction             -0.321654
# HourlyRate                          -0.032311
# JobInvolvement                      -0.498419
# JobLevel                             1.025401
# JobSatisfaction                     -0.329672
# MonthlyIncome                        1.369817
# MonthlyRate                          0.018578
# NumCompaniesWorked                   1.026471
# PercentSalaryHike                    0.821128
# PerformanceRating                    1.921883
# RelationshipSatisfaction            -0.302828
# StockOptionLevel                     0.968980
# TotalWorkingYears                    1.117172
# TrainingTimesLastYear                0.553124
# WorkLifeBalance                     -0.552480
# YearsAtCompany                       1.764529
# ...

# %% [markdown]
# Here we will remove skewness only for DistanceFromHome, MonthlyIncome columns.

# %%
data_new['DistanceFromHome'] = np.log( data_new['DistanceFromHome'] )
data_new['MonthlyIncome'] = np.log( data_new['MonthlyIncome'] )

# %% [markdown]
# ### Scaling the data Using StandardScaler.

# %%
# Dividing into Feature and Target data
x=data_new.drop(['Attritions'],axis=1)
y=data_new['Attritions']

# %%
from sklearn.preprocessing import StandardScaler

# %%
SDC=StandardScaler()
x=SDC.fit_transform(x)

# %%
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='Attritions', ylabel='count'>

# %% [markdown]
# Here we can see our output is not balanced we will now use SMOTE to balance the output.

# %%
from imblearn.over_sampling import SMOTE

# %%
X_train_over, Y_train_over =SMOTE(k_neighbors=3).fit_resample(x,y)

# %%
X_train_over.shape
# Out:
# (2466, 44)

# %%
Y_train_over.value_counts()
# Out:
# 0    1233
# 1    1233
# Name: Attritions, dtype: int64

# %%
data_new.columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'BusinessTravel_Travel_Frequently', 'BusinessTravel_Travel_Rarely',
#        'Department_Research & Development', 'Department_Sales',
#        'EducationField_Life Sciences', 'EducationField_Marketing',
#        'EducationField_Medical', 'EducationField_Other',
#        'EducationField_Technical Degree', 'Gender_Male',
#        'JobRole_Human Resources', 'JobRole_Laboratory Technician',
#        'JobRole_Manager', 'JobRole_Manufacturing Director',
# ...

# %%
dfx=pd.DataFrame(data=X_train_over, columns=['Age', 'DailyRate', 'DistanceFromHome', 'Education',
       'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
       'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
       'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager',
       'BusinessTravel_Travel_Frequently', 'BusinessTravel_Travel_Rarely',
       'Department_Research & Development', 'Department_Sales',
       'EducationField_Life Sciences', 'EducationField_Marketing',
       'EducationField_Medical', 'EducationField_Other',
       'EducationField_Technical Degree', 'Gender_Male',
       'JobRole_Human Resources', 'JobRole_Laboratory Technician',
       'JobRole_Manager', 'JobRole_Manufacturing Director',
       'JobRole_Research Director', 'JobRole_Research Scientist',
       'JobRole_Sales Executive', 'JobRole_Sales Representative',
       'MaritalStatus_Married', 'MaritalStatus_Single', 'OverTime_Yes'])

# %% [markdown]
# Here we can see over data is balance now.

# %% [markdown]
# # VIF calculation

# %%
import statsmodels.api as sm
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc_vif(x):
    vif=pd.DataFrame()
    vif['variables']=x.columns
    vif['VIF FACTOR']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif)

# %%
calc_vif(dfx)
# Out:
#                             variables  VIF FACTOR
# 0                                 Age    2.289349
# 1                           DailyRate    1.063358
# 2                    DistanceFromHome    1.068431
# 3                           Education    1.095393
# 4             EnvironmentSatisfaction    1.059486
# 5                          HourlyRate    1.047628
# 6                      JobInvolvement    1.064212
# 7                            JobLevel   10.566104
# 8                     JobSatisfaction    1.055363
# 9                       MonthlyIncome    9.162153
# 10                        MonthlyRate    1.054581
# 11                 NumCompaniesWorked    1.334521
# 12                  PercentSalaryHike    2.774620
# 13                  PerformanceRating    2.791747
# 14           RelationshipSatisfaction    1.051685
# 15                   StockOptionLevel    2.113052
# 16                  TotalWorkingYears    5.541707
# 17              TrainingTimesLastYear    1.047547
# ...

# %% [markdown]
# Lets remove drop columns having higher VIF.

# %%
dfx.drop(['Department_Research & Development'],axis=1, inplace= True)

# %%
calc_vif(dfx)
# Out:
#                            variables  VIF FACTOR
# 0                                Age    2.289346
# 1                          DailyRate    1.063352
# 2                   DistanceFromHome    1.068312
# 3                          Education    1.094743
# 4            EnvironmentSatisfaction    1.058604
# 5                         HourlyRate    1.047626
# 6                     JobInvolvement    1.063847
# 7                           JobLevel   10.562511
# 8                    JobSatisfaction    1.054516
# 9                      MonthlyIncome    9.161639
# 10                       MonthlyRate    1.054185
# 11                NumCompaniesWorked    1.333430
# 12                 PercentSalaryHike    2.774422
# 13                 PerformanceRating    2.791293
# 14          RelationshipSatisfaction    1.050321
# 15                  StockOptionLevel    2.111969
# 16                 TotalWorkingYears    5.533468
# 17             TrainingTimesLastYear    1.047366
# ...

# %%
dfx.drop(['Department_Sales'], axis=1, inplace= True)

# %%
calc_vif(dfx)
# Out:
#                            variables  VIF FACTOR
# 0                                Age    2.288530
# 1                          DailyRate    1.063340
# 2                   DistanceFromHome    1.067746
# 3                          Education    1.094616
# 4            EnvironmentSatisfaction    1.057964
# 5                         HourlyRate    1.046930
# 6                     JobInvolvement    1.061784
# 7                           JobLevel   10.562509
# 8                    JobSatisfaction    1.054042
# 9                      MonthlyIncome    9.148934
# 10                       MonthlyRate    1.053717
# 11                NumCompaniesWorked    1.332902
# 12                 PercentSalaryHike    2.763987
# 13                 PerformanceRating    2.787080
# 14          RelationshipSatisfaction    1.050216
# 15                  StockOptionLevel    2.111969
# 16                 TotalWorkingYears    5.524426
# 17             TrainingTimesLastYear    1.046879
# ...

# %%
dfx.drop(['EducationField_Medical'], axis=1, inplace = True)

# %%
calc_vif(dfx)
# Out:
#                            variables  VIF FACTOR
# 0                                Age    2.287068
# 1                          DailyRate    1.061140
# 2                   DistanceFromHome    1.066945
# 3                          Education    1.091977
# 4            EnvironmentSatisfaction    1.057893
# 5                         HourlyRate    1.046511
# 6                     JobInvolvement    1.061378
# 7                           JobLevel   10.546547
# 8                    JobSatisfaction    1.053405
# 9                      MonthlyIncome    9.129075
# 10                       MonthlyRate    1.053688
# 11                NumCompaniesWorked    1.331540
# 12                 PercentSalaryHike    2.763815
# 13                 PerformanceRating    2.786952
# 14          RelationshipSatisfaction    1.050128
# 15                  StockOptionLevel    2.110515
# 16                 TotalWorkingYears    5.524278
# 17             TrainingTimesLastYear    1.046727
# ...

# %% [markdown]
# As we can see VIF is less than 10 we will not remove any columns, and proceed further.

# %%
x=dfx
y=Y_train_over

# %%
x.shape
# Out:
# (2466, 41)

# %%
y.shape
# Out:
# (2466,)

# %% [markdown]
# # Model Design

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

from sklearn.linear_model import LogisticRegression 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier 
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# ### Chosing Best Random State

# %%
lr= LogisticRegression()
for i in range(0,1000):
    x_train, x_test, y_train, y_test= train_test_split(x,y, random_state= i, test_size= 0.20)
    lr.fit(x_train, y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)== round(accuracy_score(y_test,pred_test)*100,1):
        print("At Random state ", i, "The Model performing Well")
        print("At Random State", i)
        print("Training Accuracy score is-",accuracy_score(y_train,pred_train)*100 )
        print("Testing Accuracy Score is-", accuracy_score(y_test,pred_test)*100)
# Out:
# At Random state  1 The Model performing Well
# At Random State 1
# Training Accuracy score is- 81.99797160243408
# Testing Accuracy Score is- 81.9838056680162
# At Random state  84 The Model performing Well
# At Random State 84
# Training Accuracy score is- 82.40365111561866
# Testing Accuracy Score is- 82.38866396761134
# At Random state  134 The Model performing Well
# At Random State 134
# Training Accuracy score is- 82.55578093306288
# Testing Accuracy Score is- 82.5910931174089
# At Random state  180 The Model performing Well
# At Random State 180
# Training Accuracy score is- 82.1501014198783
# Testing Accuracy Score is- 82.18623481781377
# At Random state  182 The Model performing Well
# At Random State 182
# Training Accuracy score is- 81.84584178498986
# Testing Accuracy Score is- 81.78137651821862
# At Random state  228 The Model performing Well
# At Random State 228
# Training Accuracy score is- 82.1501014198783
# Testing Accuracy Score is- 82.18623481781377
# ...

# %% [markdown]
# At Random State 319
# Training Accuracy score is- 81.1866125760649
# Testing Accuracy Score is- 81.17408906882592

# %%
x_train_b, x_test_b, y_train_b, y_test_b= train_test_split(x,y,random_state=319,test_size=0.20)

# %%
lr.fit(x_train_b, y_train_b)
lr_pred=lr.predict(x_test_b)
print(accuracy_score(y_test_b,lr_pred))
# Out:
# 0.8178137651821862

# %%
from sklearn.metrics import classification_report 
print(confusion_matrix(y_test_b, lr_pred))
print(classification_report(y_test_b, lr_pred))
# Out:
# [[207  39]
#  [ 51 197]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82       246
#            1       0.83      0.79      0.81       248
#
#     accuracy                           0.82       494
#    macro avg       0.82      0.82      0.82       494
# weighted avg       0.82      0.82      0.82       494

# %% [markdown]
# ## Cross validation of model.

# %%
lr_pred=lr.predict(x_test_b)
from sklearn.model_selection import cross_val_score
lr_score=accuracy_score(y_test_b,lr_pred)
for j in range(2,10):
    lr_cv= cross_val_score(lr,x,y,cv=j)
    lr_cvscore=lr_cv.mean()
    print("at cv:-", j)
    print("Cross Validation scre is:-",lr_cvscore*100)
    print("Accuracy Score:-", lr_score*100)
    print("\n")
# Out:
# at cv:- 2
# Cross Validation scre is:- 81.3463098134631
# Accuracy Score:- 81.78137651821862
#
#
# at cv:- 3
# Cross Validation scre is:- 81.54906731549066
# Accuracy Score:- 81.78137651821862
#
#
# at cv:- 4
# Cross Validation scre is:- 81.50810898987561
# Accuracy Score:- 81.78137651821862
#
#
# at cv:- 5
# Cross Validation scre is:- 81.59011587323747
# Accuracy Score:- 81.78137651821862
#
#
# at cv:- 6
# Cross Validation scre is:- 81.83292781832928
# Accuracy Score:- 81.78137651821862
#
#
# at cv:- 7
# Cross Validation scre is:- 81.46867297008941
# Accuracy Score:- 81.78137651821862
#
#
# at cv:- 8
# Cross Validation scre is:- 81.59109296852016
# Accuracy Score:- 81.78137651821862
#
#
# at cv:- 9
# Cross Validation scre is:- 81.30575831305758
# Accuracy Score:- 81.78137651821862

# %% [markdown]
# at cv:- 6
# Cross Validation scre is:- 81.83292781832928
# Accuracy Score:- 81.78137651821862
#
# At cv:6 Cross val score and  Accuracy Score are having very less diffrence, Over model is perfoming well.

# %% [markdown]
# Lets Check Other Model Also

# %% [markdown]
# ## SVC

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
parameters= {'kernel':[ 'poly', 'rbf', 'sigmoid'], 'random_state': list(range(0,5)), 'gamma':['scale', 'auto'],'decision_function_shape':['ovo', 'ovr']}
svc=SVC()
clf=GridSearchCV(svc, param_grid=parameters, n_jobs=-1)
clf.fit(x_train_b, y_train_b)
print(clf.best_params_)
# Out:
# {'decision_function_shape': 'ovo', 'gamma': 'scale', 'kernel': 'rbf', 'random_state': 0}

# %%
scv=SVC(decision_function_shape='ovo', gamma='scale', kernel='rbf', random_state=0)
svc.fit(x_train_b, y_train_b)
svc.score(x_train_b, y_train_b)
svc_pred=svc.predict(x_test_b)

svc_d=accuracy_score(y_test_b, svc_pred)
print('Accuracy_core:', svc_d*100)

svc_cv= cross_val_score(svc,x,y,cv=6, scoring='accuracy')
svc_score=svc_cv.mean()
print('Cross val Score :', svc_score*100)
# Out:
# Accuracy_core: 90.48582995951418
# Cross val Score : 92.7007299270073

# %%
print(confusion_matrix(y_test_b, svc_pred))
print(classification_report(y_test_b, svc_pred))
# Out:
# [[217  29]
#  [ 18 230]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90       246
#            1       0.89      0.93      0.91       248
#
#     accuracy                           0.90       494
#    macro avg       0.91      0.90      0.90       494
# weighted avg       0.91      0.90      0.90       494

# %% [markdown]
# Accuracy_core: 90.2834008097166
# Cross val Score : 92.90348742903487
# for SVC Both the score having  greater diffrence as compare to logistic regression.
# Logistice regression still a best model.

# %% [markdown]
# ## Ensemble Techniques

# %%
from sklearn.neighbors import KNeighborsClassifier
parameters={'n_neighbors':[1,2,3,4,5],'weights':['uniform', 'distance'], 'algorithm':['ball_tree','kd_tree', 'brute'], 'leaf_size':[10,20,30,40,50]}
kn=KNeighborsClassifier()
knclf=GridSearchCV(kn,parameters)
knclf.fit(x_train_b, y_train_b)
print(knclf.best_params_)
# Out:
# {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 2, 'weights': 'uniform'}

# %%
kn=KNeighborsClassifier(algorithm='ball_tree',leaf_size=10,  n_neighbors=2, weights='uniform')
kn.fit(x_train_b, y_train_b)
kn.score(x_train_b,y_train_b)
kn_pred=kn.predict(x_test_b)

kn_score= accuracy_score(y_test_b, kn_pred)
print('accuracy_score: 0', kn_score*100)

kncvscore=cross_val_score(kn,x,y, cv=6, scoring='accuracy')
kncv_score=kncvscore.mean()
print('Cross val Score :',kncv_score*100 )
# Out:
# accuracy_score: 0 89.67611336032388
# Cross val Score : 91.40308191403082

# %%
print(confusion_matrix(y_test_b, kn_pred))
print(classification_report(y_test_b, kn_pred))
# Out:
# [[198  48]
#  [  3 245]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.80      0.89       246
#            1       0.84      0.99      0.91       248
#
#     accuracy                           0.90       494
#    macro avg       0.91      0.90      0.90       494
# weighted avg       0.91      0.90      0.90       494

# %% [markdown]
# accuracy_score: 0 89.67611336032388
# Cross val Score : 91.40308191403082
# for KNeighborsClassifier Both the score having greater diffrence as compare to logistic regression.
# Logistice regression still a best model.

# %% [markdown]
# ## RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

parameters={'n_estimators' : [50,100,150,200],'criterion':['gini', 'entropy'],'max_features':['auto','sqrt', 'log2'], 'random_state':[10,20,30,40,50]}
rf=RandomForestClassifier()
rfclf=GridSearchCV(rf, param_grid=parameters, n_jobs=-1)
rfclf.fit(x_train_b, y_train_b)
print(rfclf.best_params_)
# Out:
# {'criterion': 'entropy', 'max_features': 'log2', 'n_estimators': 150, 'random_state': 50}

# %%
rf=RandomForestClassifier(criterion='entropy', max_features='log2', n_estimators=150, random_state=50)
rf.fit(x_train_b, y_train_b)
rf.score(x_train_b,y_train_b)
rf_pred=rf.predict(x_test_b)

rf_score= accuracy_score(y_test_b, rf_pred)
print('accuracy_score: ', rf_score*100)

rfcvscore=cross_val_score(rf,x,y, cv=6, scoring='accuracy')
rfcv_score=rfcvscore.mean()
print('Cross val Score :',rfcv_score*100 )
# Out:
# accuracy_score:  93.92712550607287
# Cross val Score : 93.39010543390107

# %%
print(confusion_matrix(y_test_b, rf_pred))
print(classification_report(y_test_b, rf_pred))
# Out:
# [[240   6]
#  [ 24 224]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94       246
#            1       0.97      0.90      0.94       248
#
#     accuracy                           0.94       494
#    macro avg       0.94      0.94      0.94       494
# weighted avg       0.94      0.94      0.94       494

# %% [markdown]
# accuracy_score:  93.92712550607287
# Cross val Score : 93.39010543390107
# For RandomForestClassifier Both the score having considerable diffrence as compare to logistic regression. Logistice regression still a best model.

# %% [markdown]
# ## AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier
parameters={'n_estimators':[20,30,40,50,100],'learning_rate':[0.0001,0.001,0.01],'algorithm':['SAMME', 'SAMME.R'],'random_state':[10,20,30,40,50]}
ad=AdaBoostClassifier()
adclf=GridSearchCV(ad, param_grid=parameters, n_jobs=-1)
adclf.fit(x_train_b, y_train_b)
print(adclf.best_params_)
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 0.0001, 'n_estimators': 20, 'random_state': 10}

# %%
ad=AdaBoostClassifier(algorithm='SAMME', learning_rate= 0.0001, n_estimators= 20, random_state=10)
ad.fit(x_train_b, y_train_b)
ad.score(x_train_b,y_train_b)
ad_pred=ad.predict(x_test_b)

ad_score= accuracy_score(y_test_b, ad_pred)
print('accuracy_score: ', ad_score*100)

adcvscore=cross_val_score(ad,x,y, cv=6, scoring='accuracy')
adcv_score=adcvscore.mean()
print('Cross val Score :',adcv_score*100 )
# Out:
# accuracy_score:  70.44534412955466
# Cross val Score : 72.74939172749392

# %%
print(confusion_matrix(y_test_b, ad_pred))
print(classification_report(y_test_b, ad_pred))
# Out:
# [[179  67]
#  [ 79 169]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.73      0.71       246
#            1       0.72      0.68      0.70       248
#
#     accuracy                           0.70       494
#    macro avg       0.70      0.70      0.70       494
# weighted avg       0.70      0.70      0.70       494

# %% [markdown]
# Accuracy_score:  70.44534412955466
# Cross val Score : 72.74939172749392
# For AdaBoostClassifier Both the score having considerable diffrence as compare to logistic regression. Logistice regression still a best model.

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
parameters= {'criterion':['gini', 'entropy'],'splitter':['best','random'],'max_features':['auto','sqrt','log2'], 'min_samples_leaf':list(range(0,5))}
dt=DecisionTreeClassifier()
dtclf=GridSearchCV(dt,param_grid=parameters, n_jobs=-1)
dtclf.fit (x_train_b, y_train_b)
print(dtclf.best_params_)
# Out:
# {'criterion': 'gini', 'max_features': 'sqrt', 'min_samples_leaf': 3, 'splitter': 'best'}

# %%
dt=DecisionTreeClassifier(criterion='gini', max_features='sqrt', splitter= 'best', min_samples_leaf=3)
dt.fit(x_train_b,y_train_b)
dt.score(x_train_b, y_train_b)
dt_pred=dt.predict(x_test_b)

dt_score= accuracy_score(y_test_b, dt_pred)
print("accuracy_score", dt_score*100)

dt_cv=cross_val_score(dt,x,y,cv=6, scoring='accuracy')
dtcv_score= dt_cv.mean()
print("Cross val score is:",dtcv_score*100 )
# Out:
# accuracy_score 82.99595141700405
# Cross val score is: 82.80616382806164

# %% [markdown]
# accuracy_score 82.99595141700405
# Cross val score is: 82.80616382806164
# For DecisionTreeClassifier Both the score having considerable diffrence as compare to logistic regression. Logistice regression still a best model.

# %% [markdown]
# ## GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB
gb=GaussianNB()
gb.fit(x_train_b, y_train_b)
gb.score(x_train_b, y_train_b)
gb_pred=gb.predict(x_test_b)

gb_score=accuracy_score(y_test_b, gb_pred)
print("Accuracy Score is:", gb_score*100)

gb_cv= cross_val_score(gb, x,y,cv=6, scoring='accuracy')
gb_cvscore=gb_cv.mean()
print("Cross Val Score is :", gb_cvscore*100)
# Out:
# Accuracy Score is: 64.77732793522267
# Cross Val Score is : 66.13949716139498

# %% [markdown]
# ACcuracy Score is: 64.77732793522267
# Cross Val Score is : 66.26115166261151
# For GaussianNB Both the score having considerable diffrence as compare to logistic regression. Logistice regression still a best model.

# %% [markdown]
# ### Logistice regression model performnace is good as compared to athor modeles.

# %% [markdown]
# ##  AUC ROC Curve:

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds= roc_curve(lr_pred, y_test_b)
roc_auc= auc(fpr, tpr)

plt.figure()
plt.plot(fpr,tpr, color='darkorange', lw=10,label='ROC curve (area= %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color ='navy', lw=10, linestyle= '--')
plt.xlim([0.0, 1.0])
plt.xlim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Saving Best Model

# %%
import pickle
filename="Evaluation_Project_HR_Employee_Attrition.pkl "
pickle.dump(kn, open(filename,'wb'))

# %%
import numpy as np
a=np.array(y_test_b)
predicted= np.array(lr.predict(x_test_b))
df_com= pd.DataFrame({'original':a, 'predicted':predicted}, index= range(len(a)))
df_com
# Out:
#      original  predicted
# 0           0          0
# 1           1          1
# 2           1          1
# 3           1          0
# 4           0          0
# ..        ...        ...
# 489         0          0
# 490         0          0
# 491         1          1
# 492         0          1
# 493         0          0
#
# [494 rows x 2 columns]
